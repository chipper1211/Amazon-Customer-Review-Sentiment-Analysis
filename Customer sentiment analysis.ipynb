# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("Reviews.csv")

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['Text'].values[0]
# Out:
# 'I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.'

# %%
df.shape
# Out:
# (568454, 10)

# %%
df['Score'].value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: Score, dtype: int64

# %%
plt = df['Score'].value_counts().sort_index().plot(kind = 'bar', color = "indigo", title = "Reviews by customers")
plt.set_xlabel("Rating")
plt.set_ylabel("Count")
plt.plot()
# Out:
# []

# %%
plt = df['Score'].value_counts().sort_index().plot(kind = "pie", title = "Reviews by customers")
plt.plot()
# Out:
# []

# %%
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
updated_df = df.dropna(axis=0)
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 568411 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568411 non-null  int64
#  1   ProductId               568411 non-null  object
#  2   UserId                  568411 non-null  object
#  3   ProfileName             568411 non-null  object
#  4   HelpfulnessNumerator    568411 non-null  int64
#  5   HelpfulnessDenominator  568411 non-null  int64
#  6   Score                   568411 non-null  int64
#  7   Time                    568411 non-null  int64
#  8   Summary                 568411 non-null  object
#  9   Text                    568411 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 47.7+ MB

# %%
sentence = updated_df['Text'][1]
print(sentence)
# Out:
# Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".

# %%
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ['Product',
#  'arrived',
#  'labeled',
#  'as',
#  'Jumbo',
#  'Salted',
#  'Peanuts',
#  '...',
#  'the',
#  'peanuts',
#  'were',
#  'actually',
#  'small',
#  'sized',
#  'unsalted',
#  '.',
#  'Not',
#  'sure',
#  'if',
#  'this',
#  'was',
#  'an',
#  'error',
#  'or',
#  'if',
#  'the',
#  'vendor',
#  'intended',
#  'to',
#  'represent',
#  'the',
#  'product',
#  'as',
#  '``',
#  'Jumbo',
#  "''",
#  '.']

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
tagged = nltk.pos_tag(tokens)
tagged
# Out:
# [('Product', 'NNP'),
#  ('arrived', 'VBD'),
#  ('labeled', 'VBN'),
#  ('as', 'IN'),
#  ('Jumbo', 'NNP'),
#  ('Salted', 'NNP'),
#  ('Peanuts', 'NNP'),
#  ('...', ':'),
#  ('the', 'DT'),
#  ('peanuts', 'NNS'),
#  ('were', 'VBD'),
#  ('actually', 'RB'),
#  ('small', 'JJ'),
#  ('sized', 'VBN'),
#  ('unsalted', 'JJ'),
#  ('.', '.'),
#  ('Not', 'RB'),
#  ('sure', 'JJ'),
#  ('if', 'IN'),
#  ('this', 'DT'),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('error', 'NN'),
#  ('or', 'CC'),
#  ('if', 'IN'),
#  ('the', 'DT'),
#  ('vendor', 'NN'),
#  ('intended', 'VBN'),
#  ('to', 'TO'),
#  ('represent', 'VB'),
#  ('the', 'DT'),
#  ('product', 'NN'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('Jumbo', 'NNP'),
#  ("''", "''"),
#  ('.', '.')]

# %%
from nltk.probability import FreqDist
freq_dist = FreqDist(tokens)
print(freq_dist)
freq_dist.most_common(3)
# Out:
# <FreqDist with 31 samples and 37 outcomes>
# [('the', 3), ('as', 2), ('Jumbo', 2)]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'here', 'o', 'does', 'from', 'needn', "wasn't", "you're", 'into', 'off', 's', 've', 'mightn', 'weren', 'couldn', 'where', 'for', 'both', 'with', 'once', 'some', 'when', "doesn't", 'haven', 're', 'at', 'each', 'to', 'an', 'but', 'are', 'so', 'than', 'me', 'just', 'such', 'more', 'why', 'which', 'out', 'this', "hasn't", 'yours', 'by', 'after', 'then', 'were', 'we', 'while', 'don', 'own', "needn't", 'all', 'no', 'myself', 'too', 'she', "isn't", 'most', 'have', 'up', 'mustn', 'them', 'i', 'whom', 'shouldn', 'do', 'under', "haven't", "she's", 'their', 'or', 'not', 'now', "it's", 'our', 'be', 'there', 'because', "don't", 'how', 'been', 'is', "couldn't", 'wasn', 'on', 'doesn', 'her', 'aren', 'yourself', 'other', 'theirs', "you've", 'didn', "weren't", 'wouldn', "wouldn't", 'ourselves', 'during', 'about', 'it', "shouldn't", "didn't", 'again', 'further', 'nor', 'they', 'my', "aren't", 'the', 'he', 'that', 'was', 'yourselves', 'can', 'm', 'has', 'ain', 'you', 'themselves', 'being', "you'll", '
# ...

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('You are a good boy!')
# Out:
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4926}

# %%
sia.polarity_scores('This is so bad')
# Out:
# {'neg': 0.6, 'neu': 0.4, 'pos': 0.0, 'compound': -0.6696}

# %%
sia.polarity_scores(sentence)
# Out:
# {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.5664}

# %%
res = {}
for i, row in tqdm(updated_df.iterrows(), total=len(updated_df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/568411 [00:00<?, ?it/s]

# %%
Vaders = pd.DataFrame(res).T
Vaders = Vaders.reset_index().rename(columns = {'index': 'Id'})
Vaders = Vaders.merge(updated_df, how='left')

# %%
Vaders
# Out:
#             Id    neg    neu    pos  compound   ProductId          UserId  \
# 0            1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1            2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2            3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3            4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4            5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
# ...        ...    ...    ...    ...       ...         ...             ...
# 568406  568450  0.072  0.600  0.327    0.8589  B001EO7N10  A28KG5XORO54AY
# 568407  568451  0.190  0.697  0.114   -0.4848  B003S1WTCU  A3I8AFVPEE8KI5
# 568408  568452  0.037  0.884  0.078    0.4352  B004I613EE  A121AA1GQV751Z
# 568409  568453  0.041  0.506  0.452    0.9717  B004I613EE   A3IBEVCTXKNOH
# 568410  568454  0.000  0.846  0.154    0.4754  B001LR2CU2  A3LGQPJCZVL9UC
#
#                             ProfileName  HelpfulnessNumerator  \
# ...

# %%
ax = sns.barplot(data = Vaders, x = 'Score', y = 'compound')
ax.set_title('Compound Score from Customer star ratings')
ax.figure

# %%
ax = sns.barplot(data = Vaders, x = 'Score', y = 'pos')
ax.set_title('Positive Score distribution from Customer star ratings')
ax.figure

# %%
ax = sns.barplot(data = Vaders, x = 'Score', y = 'neg')
ax.set_title('Negative Score Distribution from Customer star ratings')
ax.figure

# %%
ax = sns.barplot(data = Vaders, x = 'Score', y = 'neu')
ax.set_title('Neutral Score distribution from Customer star ratings')
ax.figure

# %%
from transformers import AutoTokenizer

# %%
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
print(sentence)
sia.polarity_scores(sentence)
# Out:
# Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.5664}

# %%
encoded_text = tokenizer(sentence, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.50898594, 'roberta_neu': 0.45241365, 'roberta_pos': 0.038600367}

# %%
updated_df = updated_df.head(1000)

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      1000 non-null   int64
#  1   ProductId               1000 non-null   object
#  2   UserId                  1000 non-null   object
#  3   ProfileName             1000 non-null   object
#  4   HelpfulnessNumerator    1000 non-null   int64
#  5   HelpfulnessDenominator  1000 non-null   int64
#  6   Score                   1000 non-null   int64
#  7   Time                    1000 non-null   int64
#  8   Summary                 1000 non-null   object
#  9   Text                    1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 85.9+ KB

# %%
def roberta_polarity_scores(sentence):
    encoded_text = tokenizer(sentence, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict
    
res = {}
for i, row in tqdm(updated_df.iterrows(), total=len(updated_df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = roberta_polarity_scores(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke at id {myid}')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Broke at id 83
# Broke at id 187
# Broke at id 529
# Broke at id 540
# Broke at id 746
# Broke at id 863

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')

# %%
results_df.head()
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0   1      0.000      0.695      0.305          0.9441     0.009624
# 1   2      0.138      0.862      0.000         -0.5664     0.508986
# 2   3      0.091      0.754      0.155          0.8265     0.003229
# 3   4      0.000      1.000      0.000          0.0000     0.002295
# 4   5      0.000      0.552      0.448          0.9468     0.001635
#
#    roberta_neu  roberta_pos   ProductId          UserId  \
# 0     0.049980     0.940395  B001E4KFG0  A3SGXH7AUHU8GW
# 1     0.452414     0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2     0.098067     0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3     0.090219     0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4     0.010302     0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# ...

# %% [markdown]
# Combine and Compare Models

# %%
sns.pairplot(data = results_df,
            vars=['vader_neg', 'vader_neu', 'vader_pos',
                 'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27856\3016186870.py in <module>
#       4             hue='Score',
#       5             palette='tab10')
# ----> 6 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
results_df.query('Score == 1').sort_values('roberta_pos', ascending=False)['Text'].values[0]
# Out:
# "I just wanted to post here that I found small bits of plastic in this food as I was feeding my 9 month old.  Plastic!!! in food!!!! baby food!!!  So please be careful if you buy this or are considering it.<br /><br />My daughter LOVES this food-- it's actually her favorite.  This is the first time we have noticed plastic in it in over 2 months."
